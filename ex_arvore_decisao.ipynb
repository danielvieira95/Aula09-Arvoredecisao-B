# %%
import numpy as np # importa biblioteca numpy para trabalhar com valores numericos
from sklearn.model_selection import train_test_split # importa a biblioteca sklearn e o metodo para treinamento 
from sklearn.tree import DecisionTreeClassifier # Da sklearn importa a arvore de decisao
from sklearn import tree
from sklearn.metrics import accuracy_score # metricas
from sklearn.metrics import precision_score # metricas
from sklearn.metrics import recall_score # metricas
from sklearn.metrics import f1_score # metricas
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt # matplotlib
import seaborn as sns  # seaborn

# %%
# Dados de treinamento

notas = np.array([8,6,5,9,4,3,7,2,1,5,6,9,8])
classes = np.array(['bom','ruim','ruim','bom','pessimo','pessimo',
                    'bom','pessimo', 'pessimo','ruim','ruim','bom','bom'
])

# %%
# dividir dados em treino e teste
notas_treino,notas_teste,classes_treino,classes_teste = train_test_split(notas.reshape(-1,1),
                                                                         classes.reshape(-1,1),
                                                                         test_size= 0.2, random_state=42)

# %%
#cria o modelo de Machine Learning
modelo = DecisionTreeClassifier()

# %%
#Treinamento do modelo
modelo.fit(notas_treino,classes_treino)
# Out:
# DecisionTreeClassifier()

# %%
# plotar figura da árvore de decisão
fig = plt.figure(figsize=(10,8))
tree.plot_tree(modelo,feature_names=notas.tolist(),class_names=classes.tolist(),filled =True)
# Out:
# [Text(0.4, 0.8333333333333334, '8 <= 4.5\ngini = 0.66\nsamples = 10\nvalue = [3, 4, 3]\nclass = ruim'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]\nclass = ruim'),
#  Text(0.6, 0.5, '8 <= 6.5\ngini = 0.5\nsamples = 6\nvalue = [3, 0, 3]\nclass = bom'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = ruim'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]\nclass = bom')]

# %%
sns.boxplot(x=classes,y=notas)
plt.title("Notas e classificação das bebidas")
plt.xlabel("Classificação")
plt.ylabel("Notas")
# Out:
# Text(0, 0.5, 'Notas')

# %%
sns.barplot(x=classes, y=notas)
sns.set(font_scale=1)
plt.title('Notas de bebidas',fontsize=20)
plt.xlabel('Classificação',fontsize=16)
plt.ylabel('Notas',fontsize=16)
# Out:
# Text(0, 0.5, 'Notas')

# %%
#Realizando previsões
y_pred = modelo.predict(np.array([10,4,5]).reshape(-1,1))
y_pred
# Out:
# array(['bom', 'pessimo', 'ruim'], dtype='<U7')

# %%
#Realizando novas previsões
y_pred = modelo.predict(notas_teste)
y_pred
# Out:
# array(['bom', 'ruim', 'bom'], dtype='<U7')

# %%
print("Acurácia: ",accuracy_score(classes_teste,y_pred))
print("Precision: ",precision_score(y_pred,classes_teste,pos_label='ruim'))
print("Recall:",recall_score(y_pred,classes_teste,pos_label='ruim'))
print("Matriz de confusao: ",confusion_matrix(y_pred,classes_teste))
# Out:
# Acurácia:  1.0
# Precision:  1.0
# Recall: 1.0
# Matriz de confusao:  [[2 0]
#  [0 1]]
